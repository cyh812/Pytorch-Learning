# %%
import numpy as np
import torch

xy = np.loadtxt('diabetes.csv.gz', delimiter=',', dtype=np.float32)
x_data = torch.from_numpy(xy[:,:-1])
y_data = torch.from_numpy(xy[:, [-1]])

# %%
import torch
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear1 = torch.nn.Linear(8, 6)
        self.linear2 = torch.nn.Linear(6, 4)
        self.linear3 = torch.nn.Linear(4, 1)
        self.sigmoid = torch.nn.Sigmoid()
    def forward(self, x):
        x = self.sigmoid(self.linear1(x))
        x = self.sigmoid(self.linear2(x))
        x = self.sigmoid(self.linear3(x))
        return x
model = Model()

# %%
criterion = torch.nn.BCELoss(reduction='sum') # 交叉熵损失
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
for epoch in range(100):
    # Forward
    y_pred = model(x_data)
    loss = criterion(y_pred, y_data)
    print(epoch, loss.item())
    # Backward
    optimizer.zero_grad()
    loss.backward()
    # Update
    optimizer.step()
# Out:
# 0 494.66009521484375
# 1 520.6675415039062
# 2 636.7228393554688
# 3 932.196533203125
# 4 588.5453491210938
# 5 572.3458862304688
# 6 513.144287109375
# 7 508.65289306640625
# 8 499.16217041015625
# 9 496.99517822265625
# 10 493.8160400390625
# 11 492.7225341796875
# 12 491.4569091796875
# 13 490.89764404296875
# 14 490.3427429199219
# 15 490.0491638183594
# 16 489.7829895019531
# 17 489.6186218261719
# 18 489.47406005859375
# 19 489.3697814941406
# 20 489.2755126953125
# 21 489.19622802734375
# 22 489.1200256347656
# 23 489.04754638671875
# 24 488.97369384765625
# 25 488.8979797363281
# 26 488.8177795410156
# 27 488.7323913574219
# 28 488.6401062011719
# 29 488.5400390625
# 30 488.4308166503906
# 31 488.31121826171875
# 32 488.1798400878906
# 33 488.0351867675781
# 34 487.875732421875
# 35 487.699462890625
# 36 487.5042419433594
# 37 487.2878723144531
# 38 487.04742431640625
# 39 486.78009033203125
# 40 486.48193359375
# 41 486.14923095703125
# 42 485.7771301269531
# 43 485.36041259765625
# 44 484.8927917480469
# 45 484.3673400878906
# 46 483.77581787109375
# 47 483.10919189453125
# 48 482.3565368652344
# 49 481.5059509277344
# 50 480.54345703125
# 51 479.4534912109375
# 52 478.21807861328125
# 53 476.8177490234375
# 54 475.2295837402344
# 55 473.4298400878906
# 56 471.39068603515625
# 57 469.08489990234375
# 58 466.48016357421875
# 59 463.5494079589844
# 60 460.2587890625
# 61 456.5933837890625
# 62 452.5302429199219
# 63 448.12335205078125
# 64 443.4977111816406
# 65 439.4936218261719
# 66 439.63446044921875
# 67 463.0596923828125
# 68 589.8607177734375
# 69 858.2493896484375
# 70 794.6900024414062
# 71 641.0328369140625
# 72 480.8835144042969
# 73 472.2922058105469
# 74 458.3690490722656
# 75 452.43701171875
# 76 444.3872375488281
# 77 443.7999572753906
# 78 445.4176025390625
# 79 466.4439697265625
# 80 502.2655334472656
# 81 582.5037231445312
# 82 607.6795043945312
# 83 631.172119140625
# 84 522.3175659179688
# 85 527.2638549804688
# 86 479.702392578125
# 87 492.0763244628906
# 88 476.1032409667969
# 89 502.338134765625
# 90 496.3433837890625
# 91 534.5457153320312
# 92 514.5656127929688
# 93 547.3790893554688
# 94 504.91680908203125
# 95 528.652099609375
# 96 488.478759765625
# 97 510.8128662109375
# 98 481.28997802734375
# 99 506.1887512207031
